# %%
p = float(input("Enter your principal"))
r = float(input("Enter your rate in %"))
t = float(input("Enter your time(in years)"))

a = p*((1.0 + (r/100.0)*t))

print(f"The compound interest is {a:.2f}")
# Out:
# Enter your principal 555
# Enter your rate in % 3
# Enter your time(in years) 2
# The compound interest is 588.30
