# %%
pmt = float(input("Enter your principal"))
r = float(input("Enter your rate in %"))
t = float(input("Enter your time(in years)"))
n = float(input("Enter your interest number "))
a = pmt*((1.0 + (r/n)**(n*t))- 1.0)/(r/n)
print(f"The annuity plan is {a:.2f}")
# Out:
# Enter your principal 99
# Enter your rate in % 9
# Enter your time(in years) 2
# Enter your interest number  4
# The annuity plan is 28901.00
